# %% [markdown]
# # Rakesh Kumar Rath

# %% [markdown]
# ## Task 5

# %% [markdown]
# ### Task is to perform **Exploratory Data Analysis** on **Sample_Superstore** Dataset

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Load The Dataset

# %%
df = pd.read_csv('C:/Users/HP/Downloads/Sample_Superstore.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-100762   11/8/2018  11/11/2018    Second Class    CG-12520
# 1       2  CA-2016-100762   11/8/2018  11/11/2018    Second Class    CG-12520
# 2       3  CA-2016-100762   6/12/2018   6/16/2018    Second Class    DV-13045
# 3       4  CA-2016-100762  10/11/2017  10/18/2017  Standard Class    SO-20335
# 4       5  CA-2016-100867  10/11/2017  10/18/2017  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Exploring Dataset

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# #### Set Row ID as Index Column

# %%
df.set_index('Row ID', inplace = True)
df.head(3)
# Out:
#               Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-100762  11/8/2018  11/11/2018  Second Class    CG-12520
# 2       CA-2016-100762  11/8/2018  11/11/2018  Second Class    CG-12520
# 3       CA-2016-100762  6/12/2018   6/16/2018  Second Class    DV-13045
#
#           Customer Name    Segment Country/Region         City       State  \
# Row ID
# 1           Claire Gute   Consumer  United States    Henderson    Kentucky
# 2           Claire Gute   Consumer  United States    Henderson    Kentucky
# 3       Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#         Postal Code Region       Product ID         Category Sub-Category  \
# Row ID
# 1           42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 2           42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 3           90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
# ...

# %%
df.tail()
# Out:
#        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 9990        NaN  1/21/2016  1/23/2016    Second Class    TB-21400
# 9991        NaN  2/26/2019   3/3/2019  Standard Class    DB-13060
# 9992        NaN  2/26/2019   3/3/2019  Standard Class    DB-13060
# 9993        NaN  2/26/2019   3/3/2019  Standard Class    DB-13060
# 9994        NaN   5/4/2019   5/9/2019    Second Class    CC-12220
#
#            Customer Name   Segment Country/Region         City       State  \
# Row ID
# 9990    Tom Boeckenhauer  Consumer  United States        Miami     Florida
# 9991         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9992         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9993         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9994        Chris Cortes  Consumer  United States  Westminster  California
#
#         Postal Code Region       Product ID         Category Sub-Category  \
# Row ID
# ...

# %% [markdown]
# #### Dimension of Dataset

# %%
df.shape
# Out:
# (9994, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9994 entries, 1 to 9994
# Data columns (total 20 columns):
# Order ID          800 non-null object
# Order Date        9994 non-null object
# Ship Date         9994 non-null object
# Ship Mode         9994 non-null object
# Customer ID       9994 non-null object
# Customer Name     9994 non-null object
# Segment           9994 non-null object
# Country/Region    9994 non-null object
# City              9994 non-null object
# State             9994 non-null object
# Postal Code       9983 non-null float64
# Region            9994 non-null object
# Product ID        9994 non-null object
# Category          9994 non-null object
# Sub-Category      9994 non-null object
# Product Name      9994 non-null object
# Sales             9994 non-null float64
# Quantity          9994 non-null int64
# Discount          9994 non-null float64
# Profit            9994 non-null float64
# dtypes: float64(4), int64(1), object(15)
# ...

# %% [markdown]
# Out of 20 features 5 are of numerical data types and rest are object

# %% [markdown]
# #### Check for Missing Values

# %%
df.isnull().sum()
# Out:
# Order ID          9194
# Order Date           0
# Ship Date            0
# Ship Mode            0
# Customer ID          0
# Customer Name        0
# Segment              0
# Country/Region       0
# City                 0
# State                0
# Postal Code         11
# Region               0
# Product ID           0
# Category             0
# Sub-Category         0
# Product Name         0
# Sales                0
# Quantity             0
# Discount             0
# Profit               0
# dtype: int64

# %% [markdown]
# #### Number of Unique Values in Each Columns

# %%
df.nunique()
# Out:
# Order ID           296
# Order Date        1236
# Ship Date         1334
# Ship Mode            4
# Customer ID        793
# Customer Name      793
# Segment              3
# Country/Region       1
# City               531
# State               49
# Postal Code        630
# Region               4
# Product ID        1862
# Category             3
# Sub-Category        17
# Product Name      1850
# Sales             5825
# Quantity            14
# Discount            12
# Profit            7287
# dtype: int64

# %% [markdown]
# ### PairPlots

# %% [markdown]
# #### 1. Based on Category

# %%
sns.pairplot(df, hue = 'Category')
plt.show()

# %% [markdown]
# #### 2. Based on Region

# %%
sns.pairplot(df, hue = 'Region')
plt.show()

# %% [markdown]
# #### 3. Based on Segment

# %%
sns.pairplot(df, hue = 'Segment')
plt.show()

# %% [markdown]
# #### 4. Based on Ship Mode

# %%
sns.pairplot(df, hue = 'Ship Mode')
plt.show()

# %% [markdown]
# ### Dropping Unimportant Features

# %%
df.drop(['Order ID', 'Customer ID', 'Customer Name', 'Product ID', 'Product Name'], axis = 1, inplace = True)

# %% [markdown]
# ### Check for Correlation

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.022346  0.013376  0.057243 -0.028751
# Sales          -0.022346  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.013376  0.200795  1.000000  0.008623  0.066253
# Discount        0.057243 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.028751  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# #### Heatmap

# %%
plt.subplots(figsize = (12,6))
sns.heatmap(df.corr(), cmap = 'PiYG', annot = True)

# %% [markdown]
# #### From above Heatmap:
# - **Sales and Profit are Moderately Correlated**
# - **Quantity and Profit are Moderately Correlated**
# - **Discount and Profit are Negatively Correlated**

# %% [markdown]
# ### CountPlots

# %%
plt.subplots(figsize = (8,6))
sns.countplot(df['Category'])
plt.xticks(rotation = 90)
plt.title('Category', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Category')

# %%
plt.subplots(figsize = (12,8))
sns.countplot(df['Sub-Category'])
plt.xticks(rotation = 90)
plt.title('Sub-Category', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %%
fig, axs = plt.subplots(ncols = 2, figsize = (12,6))
sns.countplot(df['Ship Mode'], ax = axs[0])
sns.countplot(df['Segment'], ax = axs[1])
axs[0].set_title('Ship Mode', fontsize = 20)
axs[1].set_title('Segment', fontsize = 20)

plt.xticks(rotation = 90)
plt.show()

# %%
plt.subplots(figsize = (12,8))
sns.countplot(df['State'])
plt.xticks(rotation = 90)
plt.title('State', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'State')

# %%
fig, axs = plt.subplots(ncols = 2, figsize = (12,6))
sns.countplot(df['Region'], ax = axs[0])
sns.countplot(df['Quantity'], ax = axs[1])
axs[0].set_title('Region', fontsize = 20)
axs[1].set_title('Quantity', fontsize = 20)

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Distribution Plots

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (20,20))
sns.distplot(df['Sales'], color = 'red',  ax = axs[0][0])
sns.distplot(df['Profit'], color = 'green',  ax = axs[0][1])
sns.distplot(df['Quantity'], color = 'orange',  ax = axs[1][0])
sns.distplot(df['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()

# %% [markdown]
# ### Count Plots

# %% [markdown]
# #### 1. Ship Mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %% [markdown]
# #### Ship Mode Vs. Category and Subcategory

# %%
fig, axs = plt.subplots(ncols=2,  figsize = (20,15))
sns.countplot(x="Ship Mode", hue ='Category', data = df,  ax = axs[0])
sns.countplot(x="Ship Mode", hue ='Sub-Category', data = df,  ax = axs[1])
axs[0].set_title('Category Wise', fontsize = 20)
axs[1].set_title('Sub-category Wise', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sub-category Wise')

# %% [markdown]
# - **Ship Mode:** Maximum Dealings:- Category **(Office Supplies)** and Sub-Category **(Binders)** on Standard Class Mode
# - **Ship Mode:** Minimum Dealings:- Category **(Technology)** and Sub-Category **(Copiers)** on Same Day Mode

# %% [markdown]
# #### Category Vs. Sub-Category

# %%
plt.subplots(figsize = (20,15))
sns.countplot(x="Category", hue ='Sub-Category', data = df)
plt.title('Category Vs. Sub-category', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Category Vs. Sub-category')

# %% [markdown]
# ### High Demand Products in Different Categories
#
# - **Funiture: Furnishings and Chairs**
# - **Office Supplies: Binders and Papers**
# - **Technology: Phones and Accessories**
#
# ### Low Demand Products in Different Categories
#
# - **Furniture: Bookcases and Tables**
# - **Office Supplies: Fasteners and Supplies**
# - **Technology: Machines and Copiers**

# %% [markdown]
# #### Ship Mode Vs. Region & Segment

# %%
fig, axs = plt.subplots(ncols=2,  figsize = (20,15))
sns.countplot(x="Ship Mode", hue ='Region', data = df,  ax = axs[0])
sns.countplot(x="Ship Mode", hue ='Segment', data = df,  ax = axs[1])
axs[0].set_title('Ship Mode Vs. Region', fontsize = 20)
axs[1].set_title('Ship Mode Vs. Segement', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Ship Mode Vs. Segement')

# %% [markdown]
# #### Ship Mode Vs. Quantity

# %%
plt.subplots(figsize = (12,8))
ax = sns.countplot(x="Quantity", hue ='Ship Mode', data = df)
plt.title('Ship Mode Vs. Quantity', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Ship Mode Vs. Quantity')

# %% [markdown]
#  More the Quantity of products less is the number of dealings

# %% [markdown]
# ### 2. Region

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %% [markdown]
# #### Region Vs. Category & Sub-Category

# %%
fig, axs = plt.subplots(ncols=2,  figsize = (20,12))
sns.countplot(x="Region", hue ='Category', data = df,  ax = axs[0])
sns.countplot(x="Region", hue ='Sub-Category', data = df,  ax = axs[1])
axs[0].set_title('Region Vs. Category', fontsize = 20)
axs[1].set_title('Region Vs. Sub-category', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Region Vs. Sub-category')

# %% [markdown]
# Most of the delivery happened in **Western & Eastern** Region

# %% [markdown]
# #### Region Vs. Segement & Quantity

# %%
fig, axs = plt.subplots(ncols=2,  figsize = (20,12))
sns.countplot(x="Region", hue ='Segment', data = df,  ax = axs[0])
sns.countplot(x="Region", hue ='Quantity', data = df,  ax = axs[1])
axs[0].set_title('Region Vs. Segment', fontsize = 20)
axs[1].set_title('Region Vs. Quantity', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Region Vs. Quantity')

# %% [markdown]
# - Maximum Dealings are happening in Consumer Segement, then in Corporate and then in Home Office Segement

# %% [markdown]
# ### Sales Analysis: State Wise

# %%
df['Country/Region'].value_counts()
# Out:
# United States    9994
# Name: Country/Region, dtype: int64

# %% [markdown]
# All the states are of USA only.

# %%
df1 = df['State'].value_counts()
df1
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
df['State'].value_counts().plot(kind='bar', figsize= (20,15))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')

plt.title('State Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# - **California: Highest no.of deals**
# - **Wyoming: Lowest no.of deals**

# %%
df['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# Average number of deals per state is approximately 204

# %%
df1[df1<df['State'].value_counts().mean()].index
# Out:
# Index(['Georgia', 'Tennessee', 'Colorado', 'Indiana', 'Kentucky',
#        'Massachusetts', 'New Jersey', 'Oregon', 'Wisconsin', 'Maryland',
#        'Delaware', 'Minnesota', 'Connecticut', 'Oklahoma', 'Missouri',
#        'Alabama', 'Arkansas', 'Rhode Island', 'Mississippi', 'Utah',
#        'South Carolina', 'Louisiana', 'Nevada', 'Nebraska', 'New Mexico',
#        'Iowa', 'New Hampshire', 'Kansas', 'Idaho', 'Montana', 'South Dakota',
#        'Vermont', 'District of Columbia', 'Maine', 'North Dakota',
#        'West Virginia', 'Wyoming'],
#       dtype='object')

# %% [markdown]
# All above states are having number of deals below average no. of deals. They should improve their services and gain attention of the customers. For profit they will have to increase their no.of deals.

# %% [markdown]
# ### Sale Analysis: City Wise

# %%
df2 = df['City'].value_counts()
df2
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
# Houston            377
# Chicago            314
# Columbus           222
# San Diego          170
# Springfield        163
# Dallas             157
# Jacksonville       125
# Detroit            115
# Newark              95
# Richmond            90
# Jackson             82
# Columbia            81
# Aurora              68
# Phoenix             63
# Long Beach          61
# Arlington           60
# San Antonio         59
# Miami               57
# Louisville          57
# Rochester           53
# Charlotte           52
# Henderson           51
# Lakewood            49
# Lancaster           46
# Fairfield           45
#                   ...
# Lake Elsinore        1
# Orland Park          1
# Normal               1
# Santa Maria          1
# Norfolk              1
# Abilene              1
# Ontario              1
# Elyria               1
# Pensacola            1
# ...

# %%
df['City'].value_counts().head(50).plot(kind='bar', figsize= (20,10), color= 'green')
plt.ylabel('Frequency / Number of deals')
plt.xlabel('Cities')
plt.title('City Wise Dealings', fontsize = 20)
plt.show()

# %%
df['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# Average number of deals per cities = 19

# %%
df2[df2 < df['City'].value_counts().mean()].index
# Out:
# Index(['Hialeah', 'Chesapeake', 'Roswell', 'Westminster', 'Tallahassee',
#        'Cincinnati', 'Bakersfield', 'Cranston', 'Chester', 'Inglewood',
#        ...
#        'Redding', 'Rock Hill', 'Citrus Heights', 'Montebello',
#        'Rochester Hills', 'Lindenhurst', 'Hagerstown', 'Whittier',
#        'Grand Island', 'Waukesha'],
#       dtype='object', length=442)

# %% [markdown]
# All the above cities need to work to improve their number of dealings

# %% [markdown]
# #### List of cities (No. of Deals = 1)

# %%
citynames = list(df2[df2 == 1].index.values)

# %%
df2[df2 == 1]
# Out:
# Jupiter              1
# Iowa City            1
# Tinley Park          1
# Layton               1
# Vacaville            1
# Arlington Heights    1
# Goldsboro            1
# Kissimmee            1
# Aberdeen             1
# Glenview             1
# Ormond Beach         1
# Redwood City         1
# Port Orange          1
# La Quinta            1
# Davis                1
# Linden               1
# Springdale           1
# Conway               1
# Billings             1
# Commerce City        1
# Holyoke              1
# Portage              1
# San Luis Obispo      1
# Jefferson City       1
# Pico Rivera          1
# Margate              1
# Cheyenne             1
# Missouri City        1
# San Mateo            1
# Saint Peters         1
#                     ..
# Lake Elsinore        1
# Orland Park          1
# Normal               1
# Santa Maria          1
# Norfolk              1
# Abilene              1
# Ontario              1
# Elyria               1
# Pensacola            1
# ...

# %% [markdown]
# 70 cities are having number of deals = 1 only.

# %% [markdown]
# ### Segment Wise Analysis of Sales, Discount and Profit

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df_segment = df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
plot = df_segment.plot.pie(subplots=True, figsize=(18, 20), autopct='%1.1f%%', labels = df_segment.index)

# %% [markdown]
# ### Ship Mode Wise Analysis of Sales, Discount and Profit

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df_shipmode = df.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
plot = df_shipmode.plot.pie(subplots=True, figsize=(18, 20), autopct='%1.1f%%', labels = df_shipmode.index)

# %% [markdown]
# - **Discount and Profit is more in First Class Ship Mode**
# - **Sales is more on Same Day Ship Mode**

# %% [markdown]
# ### State Wise Analysis of Sales, Discount and Profit

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
df_state = df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
df_state
# Out:
#                             Sales  Discount      Profit
# State
# Alabama                319.846557  0.000000   94.865989
# Arizona                157.508933  0.303571  -15.303235
# Arkansas               194.635500  0.000000   66.811452
# California             228.729451  0.072764   38.171608
# Colorado               176.418231  0.316484  -35.867351
# Connecticut            163.223866  0.007317   42.823071
# Delaware               285.948635  0.006250  103.930988
# District of Columbia   286.502000  0.000000  105.958930
# Florida                233.612815  0.299347   -8.875461
# Georgia                266.825217  0.000000   88.315453
# Idaho                  208.689810  0.085714   39.367767
# Illinois               162.939230  0.390041  -25.625787
# Indiana                359.431946  0.000000  123.375411
# Iowa                   152.658667  0.000000   39.460397
# Kansas                 121.429583  0.000000   34.851813
# Kentucky               263.250000  0.000000   80.573357
# ...

# %%
plt.figure(figsize = (20,20))
plt.pie(df_state['Sales'], labels = df_state.index, autopct = '%1.1f%%')
plt.title('State Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **The highest amount(11.8%) of sales is in Wyoming State**
# - **The lowest amount(0.8%) of sales is in South Dakota state**

# %%
df_state.sort_values('Profit')[[ 'Profit']].plot(kind = 'bar', figsize = (15,10))
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
#  - Vermont at the Top
#  - Ohio at the Bottom

# %%
df_state.sort_values('Discount')[[ 'Discount']].plot(kind = 'bar', figsize = (15,10))
plt.title('State wise Discount Analysis', fontsize = 20)
plt.ylabel('Discount per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
# Illinois at the top

# %% [markdown]
# ### City Wise Sales, Discount and Profit Analysis

# %%
df_city = df.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
df_city = df_city.sort_values(['Profit'])
df_city
# Out:
#                         Sales  Discount      Profit
# City
# Bethlehem          337.926800  0.380000 -200.619160
# Champaign          151.960000  0.600000 -182.352000
# Oswego             107.326000  0.600000 -178.709200
# Round Rock         693.436114  0.274286 -169.061614
# Lancaster          215.031826  0.315217 -157.371052
# Clarksville        316.818571  0.271429 -150.764743
# Medina             275.302444  0.433333 -149.227178
# Burlington         866.723280  0.136000 -144.915088
# San Antonio        370.229288  0.383051 -123.712715
# Yuma               210.216250  0.450000 -116.497725
# Pueblo             210.867250  0.512500 -112.621487
# Normal             366.744000  0.300000 -110.023200
# Rockford           287.838909  0.509091 -104.500709
# Littleton           72.294000  0.700000  -98.801800
# Tyler               69.441200  0.640000  -88.741720
# Tamarac            353.377500  0.450000  -87.974025
# Waco               101.017867  0.520000  -86.683900
# ...

# %% [markdown]
# ### 20 cities with Higher Profit

# %%
df_city['Profit'].tail(20).plot(kind = 'bar', figsize = (15,10), color = 'red')
plt.title('20 Cities with Higher Profit', fontsize = 20)
plt.show()

# %% [markdown]
# ### 20 Cities with Least Profit

# %%
df_city['Profit'].head(20).plot(kind = 'bar', figsize = (15,10), color = 'red')
plt.title('20 Cities with Least Profit', fontsize = 20)
plt.show()

# %% [markdown]
# ### Region Wise Sales, Discount and Profit Analysis

# %%
df_region = df.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
df_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
plot = df_region.plot.pie(subplots=True, figsize=(18, 20), autopct='%1.1f%%', labels = df_region.index)

# %% [markdown]
# ### Category Wise Sales, Discount and Profit Analysis

# %%
df_category = df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
plot = df_category.plot.pie(subplots=True, figsize=(18, 20), autopct='%1.1f%%', labels = df_category.index)

# %% [markdown]
# Maximum Sales and Profit obtained in Technology Category

# %% [markdown]
# ### Sub-Category Wise Sales, Discount and Profit Analysis

# %%
df_subcategory = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_subcategory
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918
# Labels          34.303055  0.068681   15.236962
# Machines      1645.553313  0.306087   29.432669
# Paper           57.284092  0.074891   24.856620
# Phones         371.211534  0.154556   50.073938
# Storage        264.590553  0.074704   25.152277
# Supplies       245.650200  0.076842   -6.258418
# Tables         648.794771  0.261285  -55.565771

# %%
plt.figure(figsize = (20,25))
plt.pie(df_subcategory['Sales'], labels = df_subcategory.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **Max Sales : Copiers**
# - **Min Sales: Fasteners**

# %% [markdown]
# #### Based on Profit: Let's See

# %%
df_subcategory.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',figsize= (20,10),label=['Avg Sales Price($)','Profit($)'])

# %% [markdown]
# #### Based on Discount

# %%
plt.figure(figsize = (15,15))
plt.pie(df_subcategory['Discount'], labels = df_subcategory.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Discount Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - Max Discount is given on Binders
# - Min Discount is given on Labels

# %% [markdown]
# ### Quantity wise Sales, DIscount and Profit Analysis

# %%
df_quantity = df.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
# df_quantity = df_quantity['Discount'] * 100

# %%
df_quantity
# Out:
#                 Sales  Discount      Profit
# Quantity
# 1           59.234632  0.152959    8.276396
# 2          120.354488  0.154858   16.006831
# 3          175.201578  0.153329   23.667715
# 4          271.764059  0.157708   37.131310
# 5          337.936339  0.157146   40.257394
# 6          362.101960  0.166556   18.051517
# 7          395.888393  0.161980   56.579163
# 8          458.210802  0.171595   42.244342
# 9          498.083683  0.147946   68.557716
# 10         422.046737  0.190702   35.862404
# 11         463.896529  0.097059  126.275503
# 12         646.452522  0.113043   51.524609
# 13        1197.710704  0.157407  235.144481
# 14         452.826138  0.151724   93.931166

# %% [markdown]
# #### Based on Discount

# %%
plt.figure(figsize = (10,10))
plt.pie(df_quantity['Discount'], labels = df_quantity.index, autopct = '%1.1f%%')
plt.title('Quantity Wise Discount Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Based on Sales

# %%
plt.figure(figsize = (10,10))
plt.pie(df_quantity['Sales'], labels = df_quantity.index, autopct = '%1.1f%%')
plt.title('Quantity Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Based on Profit

# %%
plt.figure(figsize = (10,10))
plt.pie(df_quantity['Profit'], labels = df_quantity.index, autopct = '%1.1f%%')
plt.title('Quantity Wise Profit Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Based on Sorted Values for Profit

# %%
df_quantity.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',figsize= (20,10),label=['Avg Sales Price($)','Profit($)'])
